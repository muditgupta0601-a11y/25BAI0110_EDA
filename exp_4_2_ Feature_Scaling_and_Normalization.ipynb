# %% [markdown]
# <a href="https://colab.research.google.com/github/muditgupta0601-a11y/25BAI0110_EDA/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler

data = {
    'Age': [28, 35, 42, 30, 55],
    'Salary': [60000, 75000, 90000, 68000, 150000]
}
df = pd.DataFrame(data)
print("Original Data:\n", df, "\n")

min_max_scaler = MinMaxScaler()
df_min_max = pd.DataFrame(
    min_max_scaler.fit_transform(df),
    columns=df.columns
)
print("Min-Max Scaled Data:\n", df_min_max, "\n")

standard_scaler = StandardScaler()
df_standard = pd.DataFrame(
    standard_scaler.fit_transform(df),
    columns=df.columns
)
print("Standardized Data:\n", df_standard, "\n")

robust_scaler = RobustScaler()
df_robust = pd.DataFrame(
    robust_scaler.fit_transform(df),
    columns=df.columns
)
print("Robust Scaled Data:\n", df_robust, "\n")
# Out:
# Original Data:
#     Age  Salary
# 0   28   60000
# 1   35   75000
# 2   42   90000
# 3   30   68000
# 4   55  150000
#
# Min-Max Scaled Data:
#          Age    Salary
# 0  0.000000  0.000000
# 1  0.259259  0.166667
# 2  0.518519  0.333333
# 3  0.074074  0.088889
# 4  1.000000  1.000000
#
# Standardized Data:
#          Age    Salary
# 0 -1.022754 -0.886917
# 1 -0.306826 -0.421751
# 2  0.409101  0.043415
# 3 -0.818203 -0.638828
# 4  1.738681  1.904080
#
# Robust Scaled Data:
#          Age    Salary
# 0 -0.583333 -0.681818
# 1  0.000000  0.000000
# 2  0.583333  0.681818
# 3 -0.416667 -0.318182
# 4  1.666667  3.409091
